# %% [markdown]
# 18.04.2026 - İlim Yayma Cemiyeti - Eyüpsultan/ İstanbul
#
# Kevser Topal
#
# Algoritmalar, Veri yapılari & Yapay Zeka Uygulamaları Atölyesi

# %%
print("Merhaba Hayat..")
# Out:
# Merhaba Hayat..

# %%
import sys #import python progamlama dilinde kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/GoogleColab')
# !pwd # ilk kod blogunun ciktisini bize veren bir kod blogudur.
# Out:
# /content/drive/My Drive/GoogleColab
